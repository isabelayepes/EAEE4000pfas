# %%
# packages used in this tutorial 
import numpy as np
import scipy.stats
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#For cluster graphics
from sklearn import neighbors, datasets
from matplotlib.colors import ListedColormap

# %%
#Dataset 
df = pd.read_csv('archive_runs/v1pfas74.csv')
#print(df.head())
print(df.columns)
# Out:
# Index(['INPUT', 'FOUND_BY', 'DTXSID', 'PREFERRED_NAME', 'INCHIKEY',
#        'MOLECULAR_FORMULA', 'Number of Carbons', 'Number of Fluorines',
#        'Contains N', 'Contains O', 'Contains S', 'MONOISOTOPIC_MASS',
#        'AVERAGE_MASS', 'BIOCONCENTRATION_FACTOR_TEST_PRED',
#        'BOILING_POINT_DEGC_TEST_PRED', '48HR_DAPHNIA_LC50_MOL/L_TEST_PRED',
#        'DENSITY_G/CM^3_TEST_PRED', 'DEVTOX_TEST_PRED',
#        '96HR_FATHEAD_MINNOW_MOL/L_TEST_PRED', 'FLASH_POINT_DEGC_TEST_PRED',
#        'MELTING_POINT_DEGC_TEST_PRED', 'AMES_MUTAGENICITY_TEST_PRED',
#        'ORAL_RAT_LD50_MOL/KG_TEST_PRED', 'SURFACE_TENSION_DYN/CM_TEST_PRED',
#        'THERMAL_CONDUCTIVITY_MW/(M*K)_TEST_PRED',
#        'TETRAHYMENA_PYRIFORMIS_IGC50_MOL/L_TEST_PRED',
#        'VISCOSITY_CP_CP_TEST_PRED', 'VAPOR_PRESSURE_MMHG_TEST_PRED',
#        'WATER_SOLUBILITY_MOL/L_TEST_PRED',
#        'ATMOSPHERIC_HYDROXYLATION_RATE_(AOH)_CM3/MOLECULE*SEC_OPERA_PRED',
#        'BIOCONCENTRATION_FACTOR_OPERA_PRED',
#        'BIODEGRADATION_HALF_LIFE_DAYS_DAYS_OPERA_PRED',
#        'BOILING_POINT_DEGC_OPERA_PRED', 'HENRYS_LAW_ATM-M3/MOLE_OPERA_PRED',
#        'OPERA_KM_DAYS_OPERA_PRED',
#        'OCTANOL_AIR_PARTITION_COEFF_LOGKOA_OPERA_PRED',
#        'SOIL_ADSORPTION_COEFFICIENT_KOC_L/KG_OPERA_PRED',
#        'OCTANOL_WATER_PARTITION_LOGP_OPERA_PRED',
#        'MELTING_POINT_DEGC_OPERA_PRED', 'OPERA_PKAA_OPERA_PRED',
#        'OPERA_PKAB_OPERA_PRED', 'VAPOR_PRESSURE_MMHG_OPERA_PRED',
#        'WATER_SOLUBILITY_MOL/L_OPERA_PRED'],
#       dtype='object')

# %%
#Correlation Analysis below uses code from https://realpython.com/numpy-scipy-pandas-correlation-python/#example-scipy-correlation-calculation

# %%
array=['BIODEGRADATION_HALF_LIFE_DAYS_DAYS_OPERA_PRED','BIOCONCENTRATION_FACTOR_OPERA_PRED','Number of Carbons','Number of Fluorines','Contains N','Contains O','Contains S','MONOISOTOPIC_MASS','AVERAGE_MASS','DENSITY_G/CM^3_TEST_PRED','MELTING_POINT_DEGC_TEST_PRED','ATMOSPHERIC_HYDROXYLATION_RATE_(AOH)_CM3/MOLECULE*SEC_OPERA_PRED','BOILING_POINT_DEGC_OPERA_PRED','HENRYS_LAW_ATM-M3/MOLE_OPERA_PRED','OPERA_KM_DAYS_OPERA_PRED','OCTANOL_AIR_PARTITION_COEFF_LOGKOA_OPERA_PRED','SOIL_ADSORPTION_COEFFICIENT_KOC_L/KG_OPERA_PRED','OCTANOL_WATER_PARTITION_LOGP_OPERA_PRED','MELTING_POINT_DEGC_OPERA_PRED','VAPOR_PRESSURE_MMHG_OPERA_PRED','WATER_SOLUBILITY_MOL/L_OPERA_PRED']
results = ''
for x in array:
    j=df[x].values.astype(float)
    for y in array:
        h=df[y].values.astype(float)
        a=scipy.stats.pearsonr(j, h)
        b=scipy.stats.spearmanr(j, h)
        c=scipy.stats.kendalltau(j, h)
        newresults='{},{},{}'.format(a[0],b[0],c[0])
        results = results+newresults
        print("The Pearson's correlation between:{} and {} is {}".format(x,y,a)) # Pearson's r
        print("The Spearman's correlation between:{} and {} is {}".format(x,y,b))   # Spearman's rho
        print("The Kendall's correlation between:{} and {} is {}".format(x,y,c))  # Kendall's tau
results=sorted(results.split(','),reverse=True)
print(results)
# Out:
# The Pearson's correlation between:BIODEGRADATION_HALF_LIFE_DAYS_DAYS_OPERA_PRED and BIODEGRADATION_HALF_LIFE_DAYS_DAYS_OPERA_PRED
BIODEGRADATION_HALF_LIFE_DAYS_DAYS_OPERA_PRED is SpearmanrResult(correlation=0.411730301551641, pvalue=0.0006554839097693759)
# The Kendall's correlation between:Number of Carbons and BIODEGRADATION_HALF_LIFE_DAYS_DAYS_OPERA_PRED is KendalltauResult(correlation=0.33192685322986604, pvalue=0.00025946513801411317)
# The Pearson's correlation between:Number of Carbons and BIOCONCENTRATION_FACTOR_OPERA_PRED is (0.575191242672789, 5.397650976058082e-07)
# The Spearman's correlation between:Number of Carbons and BIOCONCENTRATION_FACTOR_OPERA_PRED is SpearmanrResult(correlation=0.3664668817656981, pvalue=0.0026783712247518093)
# The Kendall's correlation between:Number of Carbons and BIOCONCENTRATION_FACTOR_OPERA_PRED is KendalltauResult(correlation=0.27424604145216425, pvalue=0.002544691197196871)
# The Pearson's correlation between:Number of Carbons and Number of Carbons is (1.0, 0.0)
# The Spearman's correlation between:Number of Carbons and Number of Carbons is SpearmanrResult(correlation=1.0, pvalue=0.0)
# The Kendall's correlation between:Number of Carbons and Number of Carbons is KendalltauResult(correlation=0.9999999999999998, pvalue=7.635790481164864e-25)
# The Pearson's correlation between:Number of Carbons and Number of Fluorines is (0.8544053202299391, 1.4255248768944123e-19)
# The Spearman's correlation between:Number of Carbons and Number of Fluorines is SpearmanrResult(correlation=0.7949755006536449, pvalue=2.636985513174212e-15)
# The Kendall's correlation between:Number of Carbons and Number of Fluorines is KendalltauResult(correlation=0.6817350540142147, pvalue=8.501848475229037e-13)
# The Pearson's correlation between:Number of Carbons and Contains N is (0.0891267013112759, 0.4801713830011595)
# The Spearman's correlation between:Number of Carbons and Contains N is SpearmanrResult(correlation=0.05320472827558595, pvalue=0.6738094366842787)
# The Kendall's correlation between:Number of Carbons and Contains N is KendalltauResult(correlation=0.046876346421749836, pvalue=0.670371772854867)
# The Pearson's correlation between:Number of Carbons and Contains O is (0.15039165316674175, 0.2317804268120674)
# The Spearman's correlation between:Number of Carbons and Contains O is SpearmanrResult(correlation=0.1049989575428347, pvalue=0.4051788627141921)
# The Kendall's correlation between:Number of Carbons and Contains O is KendalltauResult(correlation=0.09250996419352196, pvalue=0.4009130624799073)
# The Pearson's correlation between:Number of Carbons and Contains S is (0.13005501212071188, 0.3017978943727641)
# The Spearman's correlation between:Number of Carbons and Contains S is SpearmanrResult(correlation=0.06238107249313517, pvalue=0.6215498448015435)
# The Kendall's correlation between:Number of Carbons and Contains S is KendalltauResult(correlation=0.054961219784864866, pvalue=0.6177451607459771)
# The Pearson's correlation between:Number of Carbons and MONOISOTOPIC_MASS is (0.8651609832409387, 1.506561016676132e-20)
# The Spearman's correlation between:Number of Carbons and MONOISOTOPIC_MASS is SpearmanrResult(correlation=0.8074724979529759, pvalue=4.458632814567074e-16)
# The Kendall's correlation between:Number of Carbons and MONOISOTOPIC_MASS is KendalltauResult(correlation=0.675190655851126, pvalue=1.1114491544864947e-13)
# The Pearson's correlation between:Number of Carbons and AVERAGE_MASS is (0.8650649912322059, 1.5383828564416298e-20)
# The Spearman's correlation between:Number of Carbons and AVERAGE_MASS is SpearmanrResult(correlation=0.8064937973329018, pvalue=5.148272656713253e-16)
# The Kendall's correlation between:Number of Carbons and AVERAGE_MASS is KendalltauResult(correlation=0.673092161194246, pvalue=1.3229212969244635e-13)
# The Pearson's correlation between:Number of Carbons and DENSITY_G/CM^3_TEST_PRED is (0.4126908027612589, 0.0006348017319907352)
# The Spearman's correlation between:Number of Carbons and DENSITY_G/CM^3_TEST_PRED is SpearmanrResult(correlation=0.38099537580694115, pvalue=0.0017415981004623843)
# The Kendall's correlation between:Number of Carbons and DENSITY_G/CM^3_TEST_PRED is KendalltauResult(correlation=0.2827040417641546, pvalue=0.0018686726220480366)
# The Pearson's correlation between:Number of Carbons and MELTING_POINT_DEGC_TEST_PRED is (0.08080934419434362, 0.5222296479414721)
# The Spearman's correlation between:Number of Carbons and MELTING_POINT_DEGC_TEST_PRED is SpearmanrResult(correlation=0.06181113960500465, pvalue=0.6247453255309394)
# The Kendall's correlation between:Number of Carbons and MELTING_POINT_DEGC_TEST_PRED is KendalltauResult(correlation=0.045609300117210615, pvalue=0.6156483880955677)
# The Pearson's correlation between:Number of Carbons and ATMOSPHERIC_HYDROXYLATION_RATE_(AOH)_CM3/MOLECULE*SEC_OPERA_PRED is (nan, nan)
# The Spearman's correlation between:Number of Carbons and ATMOSPHERIC_HYDROXYLATION_RATE_(AOH)_CM3/MOLECULE*SEC_OPERA_PRED is SpearmanrResult(correlation=nan, pvalue=nan)
# The Kendall's correlation between:Number of Carbons and ATMOSPHERIC_HYDROXYLATION_RATE_(AOH)_CM3/MOLECULE*SEC_OPERA_PRED is KendalltauResult(correlation=nan, pvalue=nan)
# The Pearson's correlation between:Number of Carbons and BOILING_POINT_DEGC_OPERA_PRED is (0.4448506868558703, 0.00020502325788085757)
# The Spearman's correlation between:Number of Carbons and BOILING_POINT_DEGC_OPERA_PRED is SpearmanrResult(correlation=0.4914526725701655, pvalue=3.222868745514057e-05)
# The Kendall's correlation between:Number of Carbons and BOILING_POINT_DEGC_OPERA_PRED is KendalltauResult(correlation=0.36872159807087324, pvalue=4.9765767145654044e-05)
# The Pearson's correlation between:Number of Carbons and HENRYS_LAW_ATM-M3/MOLE_OPERA_PRED is (-0.2165629066871119, 0.08314258112605545)
# The Spearman's correlation between:Number of Carbons and HENRYS_LAW_ATM-M3/MOLE_OPERA_PRED is SpearmanrResult(correlation=-0.511927698515304, pvalue=1.3081486244917185e-05)
# The Kendall's correlation between:Number of Carbons and HENRYS_LAW_ATM-M3/MOLE_OPERA_PRED is KendalltauResult(correlation=-0.37363819077360666, pvalue=4.0643343155769e-05)
# The Pearson's correlation between:Number of Carbons and OPERA_KM_DAYS_OPERA_PRED is (0.8307088005342932, 1.1288478076833397e-17)
# The Spearman's correlation between:Number of Carbons and OPERA_KM_DAYS_OPERA_PRED is SpearmanrResult(correlation=0.6723007992382855, pvalue=8.651594758666497e-10)
# The Kendall's correlation between:Number of Carbons and OPERA_KM_DAYS_OPERA_PRED is KendalltauResult(correlation=0.5427240017265582, pvalue=2.336791635405472e-09)
# The Pearson's correlation between:Number of Carbons and OCTANOL_AIR_PARTITION_COEFF_LOGKOA_OPERA_PRED is (0.4086050632021815, 0.0007270803097156314)
# The Spearman's correlation between:Number of Carbons and OCTANOL_AIR_PARTITION_COEFF_LOGKOA_OPERA_PRED is SpearmanrResult(correlation=0.485002286734214, pvalue=4.231626066884874e-05)
# The Kendall's correlation between:Number of Carbons and OCTANOL_AIR_PARTITION_COEFF_LOGKOA_OPERA_PRED is KendalltauResult(correlation=0.3834075223183618, pvalue=2.4615028992450904e-05)
# The Pearson's correlation between:Number of Carbons and SOIL_ADSORPTION_COEFFICIENT_KOC_L/KG_OPERA_PRED is (0.42645172784083435, 0.00039678465471844446)
# The Spearman's correlation between:Number of Carbons and SOIL_ADSORPTION_COEFFICIENT_KOC_L/KG_OPERA_PRED is SpearmanrResult(correlation=0.5529254803237126, pvalue=1.7865996214537335e-06)
# The Kendall's correlation between:Number of Carbons and SOIL_ADSORPTION_COEFFICIENT_KOC_L/KG_OPERA_PRED is KendalltauResult(correlation=0.4137287317509705, pvalue=5.290358445966113e-06)
# The Pearson's correlation between:Number of Carbons and OCTANOL_WATER_PARTITION_LOGP_OPERA_PRED is (0.695667946692028, 1.2617413131275355e-10)
# The Spearman's correlation between:Number of Carbons and OCTANOL_WATER_PARTITION_LOGP_OPERA_PRED is SpearmanrResult(correlation=0.7139597773288684, pvalue=2.449824958228687e-11)
# The Kendall's correlation between:Number of Carbons and OCTANOL_WATER_PARTITION_LOGP_OPERA_PRED is KendalltauResult(correlation=0.5852998766559716, pvalue=1.1530585391286433e-10)
# The Pearson's correlation between:Number of Carbons and MELTING_POINT_DEGC_OPERA_PRED is (0.37963682690314055, 0.0018146314194605073)
# The Spearman's correlation between:Number of Carbons and MELTING_POINT_DEGC_OPERA_PRED is SpearmanrResult(correlation=0.4643235878709855, pvalue=9.77374990844543e-05)
# The Kendall's correlation between:Number of Carbons and MELTING_POINT_DEGC_OPERA_PRED is KendalltauResult(correlation=0.34749071982061747, pvalue=0.00013037991103674406)
# The Pearson's correlation between:Number of Carbons and VAPOR_PRESSURE_MMHG_OPERA_PRED is (-0.2045773588286231, 0.10211357068149557)
# The Spearman's correlation between:Number of Carbons and VAPOR_PRESSURE_MMHG_OPERA_PRED is SpearmanrResult(correlation=-0.4185364963695764, pvalue=0.0005211946176737343)
# The Kendall's correlation between:Number of Carbons and VAPOR_PRESSURE_MMHG_OPERA_PRED is KendalltauResult(correlation=-0.3140982386803946, pvalue=0.0005471690226091905)
# The Pearson's correlation between:Number of Carbons and WATER_SOLUBILITY_MOL/L_OPERA_PRED is (-0.1316446698657227, 0.29587637352940466)
# The Spearman's correlation between:Number of Carbons and WATER_SOLUBILITY_MOL/L_OPERA_PRED is SpearmanrResult(correlation=-0.46113082014848583, pvalue=0.00011070018313173831)
# The Kendall's correlation between:Number of Carbons and WATER_SOLUBILITY_MOL/L_OPERA_PRED is KendalltauResult(correlation=-0.34765798371469386, pvalue=0.0001303231588924343)
# The Pearson's correlation between:Number of Fluorines and BIODEGRADATION_HALF_LIFE_DAYS_DAYS_OPERA_PRED is (0.19958233374039894, 0.11094837609915068)
# The Spearman's correlation between:Number of Fluorines and BIODEGRADATION_HALF_LIFE_DAYS_DAYS_OPERA_PRED is SpearmanrResult(correlation=0.3632678353849564, pvalue=0.002936975943706913)
# The Kendall's correlation between:Number of Fluorines and BIODEGRADATION_HALF_LIFE_DAYS_DAYS_OPERA_PRED is KendalltauResult(correlation=0.29486533974433987, pvalue=0.0009417367075032016)
# The Pearson's correlation between:Number of Fluorines and BIOCONCENTRATION_FACTOR_OPERA_PRED is (0.5132421281610483, 1.2321076825001665e-05)
# The Spearman's correlation between:Number of Fluorines and BIOCONCENTRATION_FACTOR_OPERA_PRED is SpearmanrResult(correlation=0.42762961112705533, pvalue=0.0003807855190637868)
# The Kendall's correlation between:Number of Fluorines and BIOCONCENTRATION_FACTOR_OPERA_PRED is KendalltauResult(correlation=0.31119006443606806, pvalue=0.0004821436064172665)
# The Pearson's correlation between:Number of Fluorines and Number of Carbons is (0.8544053202299391, 1.4255248768944123e-19)
# The Spearman's correlation between:Number of Fluorines and Number of Carbons is SpearmanrResult(correlation=0.7949755006536449, pvalue=2.636985513174212e-15)
# The Kendall's correlation between:Number of Fluorines and Number of Carbons is KendalltauResult(correlation=0.6817350540142147, pvalue=8.501848475229037e-13)
# The Pearson's correlation between:Number of Fluorines and Number of Fluorines is (1.0, 0.0)
# The Spearman's correlation between:Number of Fluorines and Number of Fluorines is SpearmanrResult(correlation=0.9999999999999998, pvalue=0.0)
# The Kendall's correlation between:Number of Fluorines and Number of Fluorines is KendalltauResult(correlation=0.9999999999999999, pvalue=1.0706131840069225e-26)
# The Pearson's correlation between:Number of Fluorines and Contains N is (0.1598750490164038, 0.20332166625359605)
# The Spearman's correlation between:Number of Fluorines and Contains N is SpearmanrResult(correlation=0.12935961238108454, pvalue=0.3044123147245366)
# The Kendall's correlation between:Number of Fluorines and Contains N is KendalltauResult(correlation=0.11177657571521084, pvalue=0.3007264042782397)
# The Pearson's correlation between:Number of Fluorines and Contains O is (0.15434424475367778, 0.21960086807552315)
# The Spearman's correlation between:Number of Fluorines and Contains O is SpearmanrResult(correlation=0.10949968658459103, pvalue=0.3852299627739274)
# The Kendall's correlation between:Number of Fluorines and Contains O is KendalltauResult(correlation=0.09461608444108249, pvalue=0.3810313968448653)
# The Pearson's correlation between:Number of Fluorines and Contains S is (0.3408213403004406, 0.005466456703078501)
# The Spearman's correlation between:Number of Fluorines and Contains S is SpearmanrResult(correlation=0.2955379467694876, pvalue=0.016842560261135734)
# The Kendall's correlation between:Number of Fluorines and Contains S is KendalltauResult(correlation=0.25536733664971906, pvalue=0.018064003694411947)
# The Pearson's correlation between:Number of Fluorines and MONOISOTOPIC_MASS is (0.964274451419958, 4.683244107501517e-38)
# The Spearman's correlation between:Number of Fluorines and MONOISOTOPIC_MASS is SpearmanrResult(correlation=0.9281241433320745, pvalue=9.908083523630274e-29)
# The Kendall's correlation between:Number of Fluorines and MONOISOTOPIC_MASS is KendalltauResult(correlation=0.8166295067049074, pvalue=5.3987938738089676e-20)
# The Pearson's correlation between:Number of Fluorines and AVERAGE_MASS is (0.9642147368469429, 4.931785122523376e-38)
# The Spearman's correlation between:Number of Fluorines and AVERAGE_MASS is SpearmanrResult(correlation=0.927065018712339, pvalue=1.5454887536745727e-28)
# The Kendall's correlation between:Number of Fluorines and AVERAGE_MASS is KendalltauResult(correlation=0.8145879329381451, pvalue=6.672062100246831e-20)
# The Pearson's correlation between:Number of Fluorines and DENSITY_G/CM^3_TEST_PRED is (0.6331205178562398, 1.5210290146161585e-08)
# The Spearman's correlation between:Number of Fluorines and DENSITY_G/CM^3_TEST_PRED is SpearmanrResult(correlation=0.6039084853245289, pvalue=1.0053684264860643e-07)
# The Kendall's correlation between:Number of Fluorines and DENSITY_G/CM^3_TEST_PRED is KendalltauResult(correlation=0.45618182678019736, pvalue=3.126812080535164e-07)
# The Pearson's correlation between:Number of Fluorines and MELTING_POINT_DEGC_TEST_PRED is (0.1870187499777972, 0.1357690044114525)
# The Spearman's correlation between:Number of Fluorines and MELTING_POINT_DEGC_TEST_PRED is SpearmanrResult(correlation=0.14619693729146746, pvalue=0.24520963288204545)
# The Kendall's correlation between:Number of Fluorines and MELTING_POINT_DEGC_TEST_PRED is KendalltauResult(correlation=0.11424557360626586, pvalue=0.19993617579654088)
# The Pearson's correlation between:Number of Fluorines and ATMOSPHERIC_HYDROXYLATION_RATE_(AOH)_CM3/MOLECULE*SEC_OPERA_PRED is (nan, nan)
# The Spearman's correlation between:Number of Fluorines and ATMOSPHERIC_HYDROXYLATION_RATE_(AOH)_CM3/MOLECULE*SEC_OPERA_PRED is SpearmanrResult(correlation=nan, pvalue=nan)
# The Kendall's correlation between:Number of Fluorines and ATMOSPHERIC_HYDROXYLATION_RATE_(AOH)_CM3/MOLECULE*SEC_OPERA_PRED is KendalltauResult(correlation=nan, pvalue=nan)
# The Pearson's correlation between:Number of Fluorines and BOILING_POINT_DEGC_OPERA_PRED is (0.5167617022145367, 1.0482729759691014e-05)
# The Spearman's correlation between:Number of Fluorines and BOILING_POINT_DEGC_OPERA_PRED is SpearmanrResult(correlation=0.4926587015099043, pvalue=3.061017084054387e-05)
# The Kendall's correlation between:Number of Fluorines and BOILING_POINT_DEGC_OPERA_PRED is KendalltauResult(correlation=0.3622920548254364, pvalue=4.8496818103728694e-05)
# The Pearson's correlation between:Number of Fluorines and HENRYS_LAW_ATM-M3/MOLE_OPERA_PRED is (-0.23575222197575696, 0.05868334777313419)
# The Spearman's correlation between:Number of Fluorines and HENRYS_LAW_ATM-M3/MOLE_OPERA_PRED is SpearmanrResult(correlation=-0.5045625249510589, pvalue=1.8214532160008665e-05)
# The Kendall's correlation between:Number of Fluorines and HENRYS_LAW_ATM-M3/MOLE_OPERA_PRED is KendalltauResult(correlation=-0.373217267356202, pvalue=2.9390855635632037e-05)
# The Pearson's correlation between:Number of Fluorines and OPERA_KM_DAYS_OPERA_PRED is (0.7743967997285583, 3.8256251059128033e-14)
# The Spearman's correlation between:Number of Fluorines and OPERA_KM_DAYS_OPERA_PRED is SpearmanrResult(correlation=0.5798296553742267, pvalue=4.1593883159867674e-07)
# The Kendall's correlation between:Number of Fluorines and OPERA_KM_DAYS_OPERA_PRED is KendalltauResult(correlation=0.44382845255635933, pvalue=6.416719984869666e-07)
# The Pearson's correlation between:Number of Fluorines and OCTANOL_AIR_PARTITION_COEFF_LOGKOA_OPERA_PRED is (0.34319817910212813, 0.005129032505883222)
# The Spearman's correlation between:Number of Fluorines and OCTANOL_AIR_PARTITION_COEFF_LOGKOA_OPERA_PRED is SpearmanrResult(correlation=0.4212796752028217, pvalue=0.000474544981457248)
# The Kendall's correlation between:Number of Fluorines and OCTANOL_AIR_PARTITION_COEFF_LOGKOA_OPERA_PRED is KendalltauResult(correlation=0.33575798883822133, pvalue=0.00016641477063722947)
# The Pearson's correlation between:Number of Fluorines and SOIL_ADSORPTION_COEFFICIENT_KOC_L/KG_OPERA_PRED is (0.4709136087415916, 7.528703259371704e-05)
# The Spearman's correlation between:Number of Fluorines and SOIL_ADSORPTION_COEFFICIENT_KOC_L/KG_OPERA_PRED is SpearmanrResult(correlation=0.6913429959983503, pvalue=1.8265286356274585e-10)
# The Kendall's correlation between:Number of Fluorines and SOIL_ADSORPTION_COEFFICIENT_KOC_L/KG_OPERA_PRED is KendalltauResult(correlation=0.5223911901353011, pvalue=4.644359278013504e-09)
# The Pearson's correlation between:Number of Fluorines and OCTANOL_WATER_PARTITION_LOGP_OPERA_PRED is (0.6339272295847831, 1.4396762217987365e-08)
# The Spearman's correlation between:Number of Fluorines and OCTANOL_WATER_PARTITION_LOGP_OPERA_PRED is SpearmanrResult(correlation=0.6645791902553779, pvalue=1.5743208433272306e-09)
# The Kendall's correlation between:Number of Fluorines and OCTANOL_WATER_PARTITION_LOGP_OPERA_PRED is KendalltauResult(correlation=0.5383272775888825, pvalue=1.519499448110006e-09)
# The Pearson's correlation between:Number of Fluorines and MELTING_POINT_DEGC_OPERA_PRED is (0.5282969758144662, 6.094344508797239e-06)
# The Spearman's correlation between:Number of Fluorines and MELTING_POINT_DEGC_OPERA_PRED is SpearmanrResult(correlation=0.4817650535599212, pvalue=4.841411327297995e-05)
# The Kendall's correlation between:Number of Fluorines and MELTING_POINT_DEGC_OPERA_PRED is KendalltauResult(correlation=0.35693154441731173, pvalue=6.192345965780797e-05)
# The Pearson's correlation between:Number of Fluorines and VAPOR_PRESSURE_MMHG_OPERA_PRED is (-0.17817569483894521, 0.15560285932489876)
# The Spearman's correlation between:Number of Fluorines and VAPOR_PRESSURE_MMHG_OPERA_PRED is SpearmanrResult(correlation=-0.4467814868021126, pvalue=0.00019087878295839897)
# The Kendall's correlation between:Number of Fluorines and VAPOR_PRESSURE_MMHG_OPERA_PRED is KendalltauResult(correlation=-0.3275147891277962, pvalue=0.0002391635415155026)
# The Pearson's correlation between:Number of Fluorines and WATER_SOLUBILITY_MOL/L_OPERA_PRED is (-0.18767319726125192, 0.13438067349243496)
# The Spearman's correlation between:Number of Fluorines and WATER_SOLUBILITY_MOL/L_OPERA_PRED is SpearmanrResult(correlation=-0.5376867031399418, pvalue=3.86107098321255e-06)
# The Kendall's correlation between:Number of Fluorines and WATER_SOLUBILITY_MOL/L_OPERA_PRED is KendalltauResult(correlation=-0.41321959375936906, pvalue=3.5709781388806062e-06)
# The Pearson's correlation between:Contains N and BIODEGRADATION_HALF_LIFE_DAYS_DAYS_OPERA_PRED is (0.24862764288402336, 0.0458158617717084)
# The Spearman's correlation between:Contains N and BIODEGRADATION_HALF_LIFE_DAYS_DAYS_OPERA_PRED is SpearmanrResult(correlation=0.3433874100735573, pvalue=0.005102975484066985)
# The Kendall's correlation between:Contains N and BIODEGRADATION_HALF_LIFE_DAYS_DAYS_OPERA_PRED is KendalltauResult(correlation=0.28271783784381743, pvalue=0.006012493118555637)
# The Pearson's correlation between:Contains N and BIOCONCENTRATION_FACTOR_OPERA_PRED is (0.002245415064888831, 0.9858367999752664)
# The Spearman's correlation between:Contains N and BIOCONCENTRATION_FACTOR_OPERA_PRED is SpearmanrResult(correlation=-0.11172903790453059, pvalue=0.37556961735310057)
# The Kendall's correlation between:Contains N and BIOCONCENTRATION_FACTOR_OPERA_PRED is KendalltauResult(correlation=-0.0919887890297794, pvalue=0.37141162275609796)
# The Pearson's correlation between:Contains N and Number of Carbons is (0.0891267013112759, 0.4801713830011595)
# The Spearman's correlation between:Contains N and Number of Carbons is SpearmanrResult(correlation=0.05320472827558594, pvalue=0.6738094366842788)
# The Kendall's correlation between:Contains N and Number of Carbons is KendalltauResult(correlation=0.04687634642174983, pvalue=0.670371772854867)
# The Pearson's correlation between:Contains N and Number of Fluorines is (0.1598750490164038, 0.20332166625359605)
# The Spearman's correlation between:Contains N and Number of Fluorines is SpearmanrResult(correlation=0.12935961238108457, pvalue=0.30441231472453656)
# The Kendall's correlation between:Contains N and Number of Fluorines is KendalltauResult(correlation=0.11177657571521084, pvalue=0.3007264042782397)
# The Pearson's correlation between:Contains N and Contains N is (0.9999999999999999, 0.0)
# The Spearman's correlation between:Contains N and Contains N is SpearmanrResult(correlation=1.0, pvalue=0.0)
# The Kendall's correlation between:Contains N and Contains N is KendalltauResult(correlation=1.0, pvalue=1.2441921148543658e-15)
# The Pearson's correlation between:Contains N and Contains O is (-0.1985166667941861, 0.11290729047167042)
# The Spearman's correlation between:Contains N and Contains O is SpearmanrResult(correlation=-0.19851666679418606, pvalue=0.11290729047167036)
# The Kendall's correlation between:Contains N and Contains O is KendalltauResult(correlation=-0.19851666679418603, pvalue=0.11225619196419065)
# The Pearson's correlation between:Contains N and Contains S is (0.1586103171436288, 0.20696634730428712)
# The Spearman's correlation between:Contains N and Contains S is SpearmanrResult(correlation=0.15861031714362883, pvalue=0.2069663473042872)
# The Kendall's correlation between:Contains N and Contains S is KendalltauResult(correlation=0.15861031714362883, pvalue=0.20448296149897704)
# The Pearson's correlation between:Contains N and MONOISOTOPIC_MASS is (0.1596600604643701, 0.20393797688422624)
# The Spearman's correlation between:Contains N and MONOISOTOPIC_MASS is SpearmanrResult(correlation=0.08610593453941084, pvalue=0.495234749182189)
# The Kendall's correlation between:Contains N and MONOISOTOPIC_MASS is KendalltauResult(correlation=0.07092459876256915, pvalue=0.4909192553158277)
# The Pearson's correlation between:Contains N and AVERAGE_MASS is (0.15964070547412865, 0.20399352712976754)
# The Spearman's correlation between:Contains N and AVERAGE_MASS is SpearmanrResult(correlation=0.08610593453941084, pvalue=0.495234749182189)
# The Kendall's correlation between:Contains N and AVERAGE_MASS is KendalltauResult(correlation=0.07092459876256915, pvalue=0.4909192553158277)
# The Pearson's correlation between:Contains N and DENSITY_G/CM^3_TEST_PRED is (0.04070127209927041, 0.7475204852924953)
# The Spearman's correlation between:Contains N and DENSITY_G/CM^3_TEST_PRED is SpearmanrResult(correlation=0.07072832897787436, pvalue=0.5755697330929563)
# The Kendall's correlation between:Contains N and DENSITY_G/CM^3_TEST_PRED is KendalltauResult(correlation=0.058245458481007976, pvalue=0.5715116404874646)
# The Pearson's correlation between:Contains N and MELTING_POINT_DEGC_TEST_PRED is (0.3644634959923258, 0.0028378282302255783)
# The Spearman's correlation between:Contains N and MELTING_POINT_DEGC_TEST_PRED is SpearmanrResult(correlation=0.36900930394887216, pvalue=0.0024875391705592898)
# The Kendall's correlation between:Contains N and MELTING_POINT_DEGC_TEST_PRED is KendalltauResult(correlation=0.3037430721266701, pvalue=0.003156468347366374)
# The Pearson's correlation between:Contains N and ATMOSPHERIC_HYDROXYLATION_RATE_(AOH)_CM3/MOLECULE*SEC_OPERA_PRED is (nan, nan)
# The Spearman's correlation between:Contains N and ATMOSPHERIC_HYDROXYLATION_RATE_(AOH)_CM3/MOLECULE*SEC_OPERA_PRED is SpearmanrResult(correlation=nan, pvalue=nan)
# The Kendall's correlation between:Contains N and ATMOSPHERIC_HYDROXYLATION_RATE_(AOH)_CM3/MOLECULE*SEC_OPERA_PRED is KendalltauResult(correlation=nan, pvalue=nan)
# The Pearson's correlation between:Contains N and BOILING_POINT_DEGC_OPERA_PRED is (0.15855007150262965, 0.20714110929307442)
# The Spearman's correlation between:Contains N and BOILING_POINT_DEGC_OPERA_PRED is SpearmanrResult(correlation=0.16298267112292786, pvalue=0.19456046668083427)
# The Kendall's correlation between:Contains N and BOILING_POINT_DEGC_OPERA_PRED is KendalltauResult(correlation=0.13421779563014882, pvalue=0.19228085383982596)
# The Pearson's correlation between:Contains N and HENRYS_LAW_ATM-M3/MOLE_OPERA_PRED is (-0.16292023263864874, 0.19473379218352044)
# The Spearman's correlation between:Contains N and HENRYS_LAW_ATM-M3/MOLE_OPERA_PRED is SpearmanrResult(correlation=-0.2716912309083394, pvalue=0.028574714996935424)
# The Kendall's correlation between:Contains N and HENRYS_LAW_ATM-M3/MOLE_OPERA_PRED is KendalltauResult(correlation=-0.22412858988536297, pvalue=0.02974046191015778)
# The Pearson's correlation between:Contains N and OPERA_KM_DAYS_OPERA_PRED is (0.12911711869646536, 0.3053274329922145)
# The Spearman's correlation between:Contains N and OPERA_KM_DAYS_OPERA_PRED is SpearmanrResult(correlation=-0.07072755610470285, pvalue=0.5755739168523952)
# The Kendall's correlation between:Contains N and OPERA_KM_DAYS_OPERA_PRED is KendalltauResult(correlation=-0.058231435257383286, pvalue=0.5715158440472433)
# ...
# The Spearman's correlation between:VAPOR_PRESSURE_MMHG_OPERA_PRED and MELTING_POINT_DEGC_OPERA_PRED is SpearmanrResult(correlation=-0.924800035187406, pvalue=3.9118068691995135e-28)
# The Kendall's correlation between:VAPOR_PRESSURE_MMHG_OPERA_PRED and MELTING_POINT_DEGC_OPERA_PRED is KendalltauResult(correlation=-0.757459182991719, pvalue=5.030525775814401e-19)
# The Pearson's correlation between:VAPOR_PRESSURE_MMHG_OPERA_PRED and VAPOR_PRESSURE_MMHG_OPERA_PRED is (0.9999999999999999, 0.0)
# The Spearman's correlation between:VAPOR_PRESSURE_MMHG_OPERA_PRED and VAPOR_PRESSURE_MMHG_OPERA_PRED is SpearmanrResult(correlation=0.9999999999999998, pvalue=0.0)
# The Kendall's correlation between:VAPOR_PRESSURE_MMHG_OPERA_PRED and VAPOR_PRESSURE_MMHG_OPERA_PRED is KendalltauResult(correlation=1.0, pvalue=6.286297396856571e-32)
# The Pearson's correlation between:VAPOR_PRESSURE_MMHG_OPERA_PRED and WATER_SOLUBILITY_MOL/L_OPERA_PRED is (-0.0889009715605937, 0.48128851304941267)
# The Spearman's correlation between:VAPOR_PRESSURE_MMHG_OPERA_PRED and WATER_SOLUBILITY_MOL/L_OPERA_PRED is SpearmanrResult(correlation=-0.20991323731888015, pvalue=0.09328999323265094)
# The Kendall's correlation between:VAPOR_PRESSURE_MMHG_OPERA_PRED and WATER_SOLUBILITY_MOL/L_OPERA_PRED is KendalltauResult(correlation=-0.1545498314877227, pvalue=0.06914375815626594)
# The Pearson's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and BIODEGRADATION_HALF_LIFE_DAYS_DAYS_OPERA_PRED is (0.2390165973510047, 0.05517232780438817)
# The Spearman's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and BIODEGRADATION_HALF_LIFE_DAYS_DAYS_OPERA_PRED is SpearmanrResult(correlation=-0.15650064471009897, pvalue=0.21314850216914086)
# The Kendall's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and BIODEGRADATION_HALF_LIFE_DAYS_DAYS_OPERA_PRED is KendalltauResult(correlation=-0.11699566682715457, pvalue=0.16886844923122757)
# The Pearson's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and BIOCONCENTRATION_FACTOR_OPERA_PRED is (-0.14837667364343404, 0.23816627767810652)
# The Spearman's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and BIOCONCENTRATION_FACTOR_OPERA_PRED is SpearmanrResult(correlation=-0.7750726664772603, pvalue=3.519708621163669e-14)
# The Kendall's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and BIOCONCENTRATION_FACTOR_OPERA_PRED is KendalltauResult(correlation=-0.5792007703418393, pvalue=9.672012069742212e-12)
# The Pearson's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and Number of Carbons is (-0.1316446698657227, 0.29587637352940466)
# The Spearman's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and Number of Carbons is SpearmanrResult(correlation=-0.4611308201484859, pvalue=0.00011070018313173781)
# The Kendall's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and Number of Carbons is KendalltauResult(correlation=-0.34765798371469386, pvalue=0.0001303231588924343)
# The Pearson's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and Number of Fluorines is (-0.18767319726125192, 0.13438067349243496)
# The Spearman's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and Number of Fluorines is SpearmanrResult(correlation=-0.5376867031399418, pvalue=3.86107098321255e-06)
# The Kendall's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and Number of Fluorines is KendalltauResult(correlation=-0.413219593759369, pvalue=3.5709781388806062e-06)
# The Pearson's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and Contains N is (-0.08558355690912094, 0.4978643878943667)
# The Spearman's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and Contains N is SpearmanrResult(correlation=0.08302800064465118, pvalue=0.510832798929387)
# The Kendall's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and Contains N is KendalltauResult(correlation=0.06835864138910211, pvalue=0.5065469516027477)
# The Pearson's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and Contains O is (0.07876298481784244, 0.5328533235664378)
# The Spearman's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and Contains O is SpearmanrResult(correlation=0.12168518863283807, pvalue=0.33423628771032743)
# The Kendall's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and Contains O is KendalltauResult(correlation=0.10018589039278886, pvalue=0.3303140459054076)
# The Pearson's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and Contains S is (-0.027444783437915937, 0.8281970736413299)
# The Spearman's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and Contains S is SpearmanrResult(correlation=-0.16274403224152578, pvalue=0.19522351005681535)
# The Kendall's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and Contains S is KendalltauResult(correlation=-0.13399047130892977, pvalue=0.19293270657199035)
# The Pearson's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and MONOISOTOPIC_MASS is (-0.0964353920090424, 0.4447571132721838)
# The Spearman's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and MONOISOTOPIC_MASS is SpearmanrResult(correlation=-0.3759985140419131, pvalue=0.002023934128491984)
# The Kendall's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and MONOISOTOPIC_MASS is KendalltauResult(correlation=-0.2658959846052324, pvalue=0.001774919761168589)
# The Pearson's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and AVERAGE_MASS is (-0.09642824182210462, 0.44479103300957656)
# The Spearman's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and AVERAGE_MASS is SpearmanrResult(correlation=-0.37512430219805837, pvalue=0.0020773399571824224)
# The Kendall's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and AVERAGE_MASS is KendalltauResult(correlation=-0.2658959846052324, pvalue=0.001774919761168589)
# The Pearson's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and DENSITY_G/CM^3_TEST_PRED is (0.14261956752311475, 0.2570756609892525)
# The Spearman's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and DENSITY_G/CM^3_TEST_PRED is SpearmanrResult(correlation=-0.023034978638290255, pvalue=0.8554770914695171)
# The Kendall's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and DENSITY_G/CM^3_TEST_PRED is KendalltauResult(correlation=-0.00915001230474712, pvalue=0.91433015003683)
# The Pearson's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and MELTING_POINT_DEGC_TEST_PRED is (0.3192412496126677, 0.009539887870418174)
# The Spearman's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and MELTING_POINT_DEGC_TEST_PRED is SpearmanrResult(correlation=0.2423209310093858, pvalue=0.05179431344656225)
# The Kendall's correlation between:WATER_SOLUBILITY_MOL/L_OPERA_PRED and
print('Correlation of bioconcentration and monoisotopic is {}, the p-value is {}'.format(corr_matrix, p_matrix))
corr_matrix, p_matrix = scipy.stats.pearsonr(xyz[:,0],xyz[:,2]) #biodegredation and monoisotopic correct correlation, verified with for loop above.
print('Correlation of biodegredation and monoisotopic is {}, the p-value is {}'.format(corr_matrix, p_matrix))
corr_matrix, p_matrix = scipy.stats.pearsonr(xyz[:,0],xyz[:,3]) #biodegredation and boiling_point_degC correct correlation, verified with for loop above.
print('Correlation of biodegredation and boiling_point_degCd is {}, the p-value is {}'.format(corr_matrix, p_matrix))
corr_matrix, p_matrix = scipy.stats.pearsonr(xyz[:,0],xyz[:,4]) #biodegredation and average mass correct correlation, verified with for loop above.
print('Correlation of biodegredation and average mass is {}, the p-value is {}'.format(corr_matrix, p_matrix))
corr_matrix, p_matrix = scipy.stats.pearsonr(xyz[:,2],xyz[:,4]) #average mass and monoisotopic correct correlation, verified with for loop above.
print('Correlation of average mass and monoisotopic is {}, the p-value is {}'.format(corr_matrix, p_matrix))
array = [0,1,2]
for i in array:
    corr_matrix = np.corrcoef(xyz.T[i:i+3,:]).round(decimals=3) #correlation matrix for 3 by 3 features
    print(corr_matrix)
    fig, ax = plt.subplots()
    im = ax.imshow(corr_matrix)
    im.set_clim(-1, 1)
    ax.grid(False)
    a='x'
    b='y'
    c='z'
    if i==0: 
        a='BIODEGRADATION_HALF_LIFE_DAYS_DAYS_OPERA_PRED' 
        b='BIOCONCENTRATION_FACTOR_OPERA_PRED' 
        c='MONOISOTOPIC_MASS'
    if i==1: 
        a='BIOCONCENTRATION_FACTOR_OPERA_PRED' 
        b='MONOISOTOPIC_MASS' 
        c='BOILING_POINT_DEGC_OPERA_PRED'
    if i==2: 
        a='MONOISOTOPIC_MASS'
        b='BOILING_POINT_DEGC_OPERA_PRED'
        c='AVERAGE_MASS'
    if i==3: 
        a='BOILING_POINT_DEGC_OPERA_PRED'
        b='AVERAGE_MASS'
    if i==4: 
        a='AVERAGE_MASS'
    ax.xaxis.set(ticks=(0, 1, 2), ticklabels=('x', 'y', 'z'))
    ax.yaxis.set(ticks=(0, 1, 2), ticklabels=(a, b, c))
    ax.set_ylim(2.5, -0.5)
    for i in range(3):
        for j in range(3):
            ax.text(j, i, corr_matrix[i, j], ha='center', va='center',
                    color='r')
    cbar = ax.figure.colorbar(im, ax=ax, format='% .2f')
    plt.show()
# Out:
# Correlation of biodegredation and bioconcentration is 0.19096819942353715, the p-value is 0.12755298903989545
# Correlation of bioconcentration and monoisotopic is 0.4256546027613209, the p-value is 0.0004079571196278937
# Correlation of biodegredation and monoisotopic is 0.16993404312585791, the p-value is 0.17594862258677854
# Correlation of biodegredation and boiling_point_degCd is 0.2519183461482256, the p-value is 0.04292912343220103
# Correlation of biodegredation and average mass is 0.16989416624430703, the p-value is 0.17605155616139964
# Correlation of average mass and monoisotopic is 0.9999999318201841, the p-value is 5.535404435490706e-218
# [[1.    0.191 0.17 ]
#  [0.191 1.    0.426]
#  [0.17  0.426 1.   ]]
# [[ 1.     0.426 -0.036]
#  [ 0.426  1.     0.641]
#  [-0.036  0.641  1.   ]]
# [[1.    0.641 1.   ]
#  [0.641 1.    0.641]
#  [1.    0.641 1.   ]]

# %%
# Get an idea of the distribution
features=['BIODEGRADATION_HALF_LIFE_DAYS_DAYS_OPERA_PRED','Number of Carbons','Number of Fluorines','Contains N','Contains O','Contains S','MONOISOTOPIC_MASS','AVERAGE_MASS','DENSITY_G/CM^3_TEST_PRED','MELTING_POINT_DEGC_TEST_PRED','ATMOSPHERIC_HYDROXYLATION_RATE_(AOH)_CM3/MOLECULE*SEC_OPERA_PRED','BOILING_POINT_DEGC_OPERA_PRED','HENRYS_LAW_ATM-M3/MOLE_OPERA_PRED','OPERA_KM_DAYS_OPERA_PRED','OCTANOL_AIR_PARTITION_COEFF_LOGKOA_OPERA_PRED','SOIL_ADSORPTION_COEFFICIENT_KOC_L/KG_OPERA_PRED','OCTANOL_WATER_PARTITION_LOGP_OPERA_PRED','MELTING_POINT_DEGC_OPERA_PRED','VAPOR_PRESSURE_MMHG_OPERA_PRED','WATER_SOLUBILITY_MOL/L_OPERA_PRED']
for i in features:
    j=df[i].values.astype(float)
    # %matplotlib inline 
    sns.distplot(j, hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}).set(title='Original Distribution of '+i)
    plt.show()
# Out:
# /Users/isabelayepes/opt/anaconda3/envs/keras/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/isabelayepes/opt/anaconda3/envs/keras/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/isabelayepes/opt/anaconda3/envs/keras/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/isabelayepes/opt/anaconda3/envs/keras/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/isabelayepes/opt/anaconda3/envs/keras/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/isabelayepes/opt/anaconda3/envs/keras/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/isabelayepes/opt/anaconda3/envs/keras/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/isabelayepes/opt/anaconda3/envs/keras/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/jv/lz3tf5xn1vdbnrsqnz5bfz0r0000gn/T/ipykernel_37523/3942771143.py in <module>
#       2 features=['BIODEGRADATION_HALF_LIFE_DAYS_DAYS_OPERA_PRED','Number of Carbons','Number of Fluorines','Contains N','Contains O','Contains S','MONOISOTOPIC_MASS','AVERAGE_MASS','DENSITY_G/CM^3_TEST_PRED','MELTING_POINT_DEGC_TEST_PRED','ATMOSPHERIC_HYDROXYLATION_RATE_(AOH)_CM3/MOLECULE*SEC_OPERA_PRED','BOILING_POINT_DEGC_OPERA_PRED','HENRYS_LAW_ATM-M3/MOLE_OPERA_PRED','OPERA_KM_DAYS_OPERA_PRED','OCTANOL_AIR_PARTITION_COEFF_LOGKOA_OPERA_PRED','SOIL_ADSORPTION_COEFFICIENT_KOC_L/KG_OPERA_PRED','OCTANOL_WATER_PARTITION_LOGP_OPERA_PRED','MELTING_POINT_DEGC_OPERA_PRED','VAPOR_PRESSURE_MMHG_OPERA_PRED','WATER_SOLUBILITY_MOL/L_OPERA_PRED']
#       3 for i in features:
# ----> 4     j=df[i].values.astype(float)
#       5     get_ipython().run_line_magic('matplotlib', 'inline')
#       6     sns.distplot(j, hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}).set(title='Original Distribution of '+i)
#
# ValueError: could not convert string to float:

# %%
print(df.shape)
# Out:
# (65, 21)

# %%
print(df.dtypes)
# Out:
# INPUT                                                                object
# FOUND_BY                                                             object
# DTXSID                                                               object
# PREFERRED_NAME                                                       object
# INCHIKEY                                                             object
# MOLECULAR_FORMULA                                                    object
# Number of Carbons                                                     int64
# Number of Fluorines                                                   int64
# Contains N                                                            int64
# Contains O                                                            int64
# Contains S                                                            int64
# MONOISOTOPIC_MASS                                                   float64
# AVERAGE_MASS                                                        float64
# BIOCONCENTRATION_FACTOR_TEST_PRED                                    object
# BOILING_POINT_DEGC_TEST_PRED                                         object
# 48HR_DAPHNIA_LC50_MOL/L_TEST_PRED                                    object
# DENSITY_G/CM^3_TEST_PRED                                             object
# DEVTOX_TEST_PRED                                                     object
# 96HR_FATHEAD_MINNOW_MOL/L_TEST_PRED                                  object
# FLASH_POINT_DEGC_TEST_PRED                                           object
# MELTING_POINT_DEGC_TEST_PRED                                         object
# AMES_MUTAGENICITY_TEST_PRED                                          object
# ORAL_RAT_LD50_MOL/KG_TEST_PRED                                       object
# SURFACE_TENSION_DYN/CM_TEST_PRED                                     object
# THERMAL_CONDUCTIVITY_MW/(M*K)_TEST_PRED                              object
# TETRAHYMENA_PYRIFORMIS_IGC50_MOL/L_TEST_PRED                         object
# VISCOSITY_CP_CP_TEST_PRED                                            object
# VAPOR_PRESSURE_MMHG_TEST_PRED                                        object
# WATER_SOLUBILITY_MOL/L_TEST_PRED                                     object
# ATMOSPHERIC_HYDROXYLATION_RATE_(AOH)_CM3/MOLECULE*SEC_OPERA_PRED      int64
# BIOCONCENTRATION_FACTOR_OPERA_PRED                                  float64
# BIODEGRADATION_HALF_LIFE_DAYS_DAYS_OPERA_PRED                       float64
# BOILING_POINT_DEGC_OPERA_PRED                                       float64
# HENRYS_LAW_ATM-M3/MOLE_OPERA_PRED                                   float64
# OPERA_KM_DAYS_OPERA_PRED                                            float64
# OCTANOL_AIR_PARTITION_COEFF_LOGKOA_OPERA_PRED                       float64
# SOIL_ADSORPTION_COEFFICIENT_KOC_L/KG_OPERA_PRED                     float64
# OCTANOL_WATER_PARTITION_LOGP_OPERA_PRED                             float64
# MELTING_POINT_DEGC_OPERA_PRED                                       float64
# OPERA_PKAA_OPERA_PRED                                                object
# OPERA_PKAB_OPERA_PRED                                                object
# VAPOR_PRESSURE_MMHG_OPERA_PRED                                      float64
# WATER_SOLUBILITY_MOL/L_OPERA_PRED                                   float64
# dtype: object

# %%
#if running again this clears old column
if 'BIODEGRADATION_HALF_LIFE_DAYS_DAYS_CATEGORIES' in df.columns:
    df= df.drop(labels='BIODEGRADATION_HALF_LIFE_DAYS_DAYS_CATEGORIES', axis=1)
#add a new column to df for halflife category low (between 0 and 3.9), medium (greater than 3.9 up to 4.5), high (greater than 4.5 up to 9). 
category = pd.cut(df['BIODEGRADATION_HALF_LIFE_DAYS_DAYS_OPERA_PRED'],bins=[0,3.9,4.5,9],labels=[0,1,2])
df.insert(5,'BIODEGRADATION_HALF_LIFE_DAYS_DAYS_CATEGORIES',category)
#df['BIODEGRADATION_HALF_LIFE_DAYS_DAYS_BINARY'] = np.where(df['BIODEGRADATION_HALF_LIFE_DAYS_DAYS_OPERA_PRED']>4.5, 1, 0)
y= df['BIODEGRADATION_HALF_LIFE_DAYS_DAYS_CATEGORIES']
#print(y)
#Analyzes category distribution
df['BIODEGRADATION_HALF_LIFE_DAYS_DAYS_CATEGORIES'].value_counts(normalize=True)
# Out:
# 1    0.415385
# 2    0.338462
# 0    0.246154
# Name: BIODEGRADATION_HALF_LIFE_DAYS_DAYS_CATEGORIES, dtype: float64

# %%
array = ['Number of Fluorines','Number of Carbons','Contains N','Contains O','Contains S']
for a in array:
# let's only use the top two features from v2ref74 model, MONOISOTOPIC_MASS and Number of Fluorines
    b='MONOISOTOPIC_MASS'
    #print(df[a].dtypes,df[b].dtypes)
    df[a]=df[a].values.astype(int)
    #print(df[a].dtypes,df[b].dtypes)
    x=df[[a,b]]
    #print(x)
    # Create an instance of Neighbours Classifier and fit the data.
    clf = neighbors.KNeighborsClassifier(n_neighbors=15, weights='uniform')
    clf.fit(x, y);
    # Plot the decision boundary
    xx, yy = np.meshgrid(np.arange(x.iloc[:, 0].min(), x.iloc[:, 0].max()+0.2, 0.2),
                         np.arange(x.iloc[:, 1].min(), x.iloc[:, 1].max()+0.2, 0.2))
    z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    z = z.reshape(xx.shape)
    plt.figure()
    plt.pcolormesh(xx, yy, z, cmap=ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF']))
    plt.scatter(x.iloc[:, 0], x.iloc[:, 1], c=y, edgecolor='k', s=20, cmap=ListedColormap(['#FF0000', '#00FF00', '#0000FF']))
    plt.title(b+ ' vs '+a)
    plt.xlabel(a)
    plt.ylabel(b)
    plt.show()
